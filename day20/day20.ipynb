# %% [markdown]
# # Day 20, 4.27.18

# %% [markdown]
# Today, I worked on the dodge game. I pretty much rewrote the previous script.

# %% [markdown]
# I have yet to add the print the score, start, and end screen functions, the 'die when hit' function, and the destroy obstacle once out of screen function.

# %% [markdown]
# ![image.png](attachment:image.png)
