# %% [markdown]
# # Day 15, 4.22.18

# %% [markdown]
# I used instructions from https://pythonprogramming.net/pygame-python-3-part-1-intro/ to build a graphic dodging game, modifying aspects of the screen's appearance.

# %% [markdown]
# ![dodgescrn.png](attachment:dodgescrn.png)
